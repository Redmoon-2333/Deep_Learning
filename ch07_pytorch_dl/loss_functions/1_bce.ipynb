# %%
import torch
import torch.nn as nn

# %%
# 输入数据
input=torch.randn(3,2)
print(input)
# 得到预测概率
pred=torch.sigmoid(input)
print(pred)
# Out:
# tensor([[ 1.2066, -0.7230],
#         [ 0.1308,  0.9184],
#         [-0.8033,  0.4414]])
# tensor([[0.7697, 0.3267],
#         [0.5327, 0.7147],
#         [0.3093, 0.6086]])

# %%
# 目标值
target=torch.tensor([[0,1],[1,0],[0,1]]).float()

# %%
# 定义损失函数
loss=nn.BCELoss()
print(loss(pred,target))
# Out:
# tensor(0.8896)
