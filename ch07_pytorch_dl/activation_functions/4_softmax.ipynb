# %%
import matplotlib.pyplot as plt
import torch

# %%
x=torch.randn(3,5)
print(x)
# Out:
# tensor([[ 0.2352,  0.0335,  0.5506,  1.3670, -0.1331],
#         [ 1.4719, -0.7577, -1.0009,  0.6182, -0.8343],
#         [-1.0199, -0.4569, -0.0203, -0.1837,  1.1411]])

# %%
y=torch.softmax(x,dim=1)
print(y)
# Out:
# tensor([[0.1432, 0.1171, 0.1964, 0.4442, 0.0991],
#         [0.5823, 0.0626, 0.0491, 0.2480, 0.0580],
#         [0.0608, 0.1067, 0.1651, 0.1402, 0.5273]])
