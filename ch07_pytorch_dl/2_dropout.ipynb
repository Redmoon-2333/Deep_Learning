# %%
import torch
import torch.nn as nn

# %%
x=torch.randint(1,10,(10,),dtype=torch.float32)

# %%
# 定义一个dropout层
dropout = nn.Dropout(0.5)

# %%
y=dropout(x)
print(x)
print(y)
# Out:
# tensor([1., 7., 3., 2., 7., 4., 7., 5., 5., 6.])
# tensor([ 0., 14.,  6.,  4., 14.,  8., 14.,  0., 10., 12.])
